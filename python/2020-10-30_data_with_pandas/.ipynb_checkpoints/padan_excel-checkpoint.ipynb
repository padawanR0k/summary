# %%
import pandas as pd

# %%
pd.read_excel('./ganam_medical_treval.xls')
# Out:
#      의료기관번호          기관명  기관분류  기관장명  코디네이터                         이메일  \
# 0       654      비오페이스의원  피부미용   NaN    NaN          service@bioface.kr
# 1       653     에프아이성형외과  성형외과   NaN    NaN            plasty@naver.com
# 2       643         힐링안과    안과   NaN    NaN  healingeyeclinic@naver.com
# 3       634        클린피부과  피부미용   NaN    NaN       1010jerry@hanmail.net
# 4       633     에이탑 성형외과  성형외과   NaN    NaN        atopps0410@naver.com
# ..      ...          ...   ...   ...    ...                         ...
# 247     466        정관복원술   NaN   NaN    NaN                         NaN
# 248     467       추간판탈출증   NaN   NaN    NaN                         NaN
# 249     468        척추고정술   NaN   NaN    NaN                         NaN
# 250     469   무릎인공관절 전치술   NaN   NaN    NaN                         NaN
# 251     470  고관절인공관절 전치술   NaN   NaN    NaN                         NaN
#
#      지역구분(구,동)                                  주소             상세주소  우편번호  \
# ...
